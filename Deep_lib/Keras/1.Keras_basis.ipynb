# %% [markdown]
# # Image processing With Keras

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Les Axes d'une Image
#
# Souvent composée de matrice Numpy à 3 dimension: *ex* *`img[550, 500, 3`*

# %%
img = plt.imread('../../Image_processing/data/pmz.jpg')

# %%
img.shape
# Out:
# (900, 900, 3)

# %%
plt.imshow(img)
