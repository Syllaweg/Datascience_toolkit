# %% [markdown]
# # *V Mask and Noise*
# ***masques et bruits***

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from helpers import show_image

# %%
img = plt.imread('data/pmz1.jpg')

# %%
defect_image = plt.imread('data/damaged_astronaut.png')

# %% [markdown]
# ## Appliquer des masques sur des images
# Avec des masques il est possible:
# - de restaurer des parties manquantes d'images
# - cacher des parties voulues d'une image
#
# ### Restaurer à l'aide de masques

# %%
from skimage.restoration import inpaint

# %%
# Show the defective image
show_image(defect_image, 'Image to restore')

# %% [markdown]
# A faire:
# - besoins de donner au mask les coordonnées des troues

# %%
mask = get_mask(defect_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7852bca6948c> in <module>
# ----> 1 mask = get_mask(defect_image)
#
# NameError: name 'get_mask' is not defined

# %%
# Apply the restoration function to the image using the mask
restored_image = inpaint.inpaint_biharmonic(defect_image, mask, multichannel=True)
show_image(restored_image)

# %% [markdown]
# ## Le Bruit dans une Image

# %% [markdown]
# ### Ajouter du bruit

# %%
from skimage.util import random_noise

# %%
# Add noise to the image
noisy_image = random_noise(img)

# %%
# Show original and resulting image
show_image(img, 'Original')
show_image(noisy_image, 'Noisy image')

# %% [markdown]
# ### Enlever le Bruit en conservant les contours lissent
# Il existe plusieurs Algo de "débruitage" d'images tous présent dans skimage.restoration

# %%
img1 = plt.imread('data/panneau_droit.png')

# %%
# Import bilateral denoising function
from skimage.restoration import denoise_bilateral

# %%
# Apply bilateral filter denoising
denoised_image = denoise_bilateral(img1, 
                                   multichannel=True)

# %%
# Show original and resulting images
show_image(img1, 'Noisy image')
show_image(denoised_image, 'Denoised image')

# %% [markdown]
# Ici l'image n'était pas bruité donc czla à juste lissé les angles
